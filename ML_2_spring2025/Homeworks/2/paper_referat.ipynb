# %% [markdown]
# # Разбор статьи по машинному обучению
#
# Количество баллов: 8 баллов
# Формат сдачи:
# - Разбор статьи должен быть оформлен в виде текстового документа (формат .docx или .pdf).
# - Название файла должно содержать вашу фамилию и номер статьи, например: *Иванов_Статья1.docx*.
# - В документе должны быть четко выделены ответы на общие и специальные вопросы. Чтобы было понятно на какой вопрос вы дали ответ.
# - ❗️Важно – вы должны выбрать только одну из предложенных статей для разбора. Ответить нужно на 8 вопросов по выбранной статье.
#
# ---
#
# ### Общие вопросы (3 балла)
#
# Ответьте на следующие вопросы, связанные с выбранной статьей:
#
# 1. Какую задачу решают авторы? (не более 200 слов)
# 2. Какова основная идея предлагаемого авторами решения поставленной задачи? (не более 300 слов)
# 3. Каковы результаты, полученные авторами? (оформите в виде списка, не более 200 слов)
#
# Примечания:
# - Ответы на общие вопросы оцениваются по 1 баллу за каждый.
# - Строго соблюдайте ограничения по количеству слов. Если ответ превышает указанный лимит, оцениваться будут только первые 200/300 слов.
# - Ответы должны быть написаны на русском языке.
#
# ---
#
# ### Специальные вопросы (5 баллов)
#
# Для каждой статьи подготовлены специальные вопросы, которые помогут глубже понять её содержание. Ответьте на 5 специальных вопросов, соответствующих выбранной статье.
#
# Примечания:
# - Ответы на специальные вопросы оцениваются по 1 баллу за каждый.
# - Ответы должны быть краткими, но содержательными.
#
# ---
#
# ### Требования к оформлению и содержанию:
# 1. Качество анализа:
#    - Не пересказывайте статью дословно. Ваша задача — продемонстрировать понимание ключевых идей, методов и результатов.
#    - Избегайте избыточного использования формул без объяснения их смысла.
#    - Используйте иллюстрации только в том случае, если они помогают лучше раскрыть содержание статьи.
#
# 2. Примеры того, как делать не надо:
#    - Не пишите: «Авторы получили качество в 38 BLEU». Объясните, почему этот результат важен и как он соотносится с целями исследования.
#    - Не ограничивайтесь общими фразами без конкретики.
#
# 3. Баланс между формулами и смыслом:
#    - Формулы должны сопровождаться объяснением их логики и роли в решении задачи.
#    - Избегайте избыточного использования технического жаргона без пояснений.
#
# ---
#
# ### Список статей для выбора:
#
# Статья 1
# Прочитайте статью: [An Image is Worth 16x16 Words: Transformers for Image Recognition at Scale](https://arxiv.org/pdf/2010.11929)
# Специальные вопросы:
# 1. Как авторы адаптировали архитектуру трансформера для обработки изображений?
# 2. Почему трансформеры требуют больших объёмов данных для обучения по сравнению со сверточными нейронными сетями (CNN)?
# 3. Какой подход использовался для обработки позиций патчей в изображении? Какие ещё варианты были рассмотрены, и каковы результаты сравнения?
# 4. Какие преимущества и недостатки трансформеров для визуальных данных по сравнению со сверточными архитектурами?
# 5. Почему модели ViT требуют меньше вычислительных ресурсов для обучения по сравнению с современными CNN?
#
# Статья 2
# Прочитайте статью: [DeepSeek-V3 Technical Report](https://arxiv.org/pdf/2412.19437)
# Специальные вопросы:
# 1. Опишите архитектуру модели DeepSeek v3.
# 2. Какие этапы были включены в процесс обучения DeepSeek v3?
# 3. Опишите нововведения в DeepSeek v3, относительно предыдущей модели DeepSeek v2.
# 4. Какой подход использовался для расширения контекстного окна модели, и какие преимущества это дало?
# 5. Какие инфраструктурные улучшения были использованы в статье и с какой целью?
#
# Статья 3
# Прочитайте статью: [Spherical CNNs](https://arxiv.org/pdf/1801.10130)
# Специальные вопросы:
# 1. В чём заключается смысл понятия эквивариантности? Являются ли обычные свёртки эквивариантными относительно каких-либо преобразований?
# 2. Зачем нужны и чем отличаются Spherical Correlation и Rotation Group Correlation?
# 3. Как организовать предсказание числовых значений или логитов для задачи классификации или регрессии, если внутри сети используются сферические свёртки?
# 4. Объясните своими словами, как авторы предлагают эффективно вычислять Spherical Correlation или Rotation Group Correlation (достаточно описать один из методов)?
# 5. Как авторы проверяли эффективность предложенной модели, и какие результаты были получены?
#
# Статья 4
# Прочитайте статью: [The Super Weight in Large Language Models](https://arxiv.org/pdf/2411.07191)
# Специальные вопросы:
# 1. Что такое super weights в контексте LLM, и каково их типичное количество?
# 2. Каким образом можно идентифицировать super weights без использования данных, и в каких слоях модели они обычно находятся?
# 3. Что такое super activations, и как они связаны с super weights?
# 4. Какое влияние оказывают super weights на предсказания и как влияет pruning весов, отличных от super weights, на результаты?
# 5. Какие методы предложены для улучшения квантизации?
#
# ---
#
# Важно:
# - Выбор статьи должен быть осознанным. Обратите внимание на тематику и сложность статьи перед началом работы.
#
# ---
#
# ### Примеры как надо и как не надо делать:
#
# * Сама по себе новая архитектура нейронной сети не является результатом. Это лишь средство для достижения результата. Результат обычно измеряется числами.
# * Не пишите просто «авторы получили качество в 38 BLEU», ведь не в этом дело. Возможно, им удалось превзойти все существующие архитектуры, или архитектуры из определённого класса, или им не удалось никого превзойти, но они просто хорошо провели время, греясь у работающих GPU (хорошо им!). Авторы явно преследовали какую-то цель, и они должны были показать, что в какой-то мере достигли её, а то бы их статью не приняли на конференцию.
# * Наверное, иллюстрации мы не будем переводить в слова, так что добавляйте их при необходимости, но это не значит, что мы открываем конкурс «скажи это картинками» 🙂 Картинка должна содержательно иллюстрировать что-то в тексте вашего разбора.
# * Старайтесь соблюдать баланс между формулами и сутью. С одной стороны, важно, чтобы вы объясняли смыслы, стоящие за формулами. Например, не надо, пожалуйста, определять механизм внимания, как куча формул + непонятная картинка из статьи Bahdanau. Механизм внимания — это в первую очередь способ использовать не только скрытое состояние декодера, но и информацию о каждом токене в исходной последовательности. Поверьте, везде за формулами стоит какая-то (пусть даже порой и немного извращённая) логика, и вам нужно её раскрыть! С другой стороны, одни общие слова без конкретики (которую чаще всего воплощают формулы) тоже бессильны.
#
#  ---
#
# Удачи в выполнении задания! 🙂
